# %% [markdown]
# ## Loading the folder
#
# edit this part by yourself in order to locate the current directory in the common/test directory

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2022 NVIDIA Corporation
# Built on Wed_Sep_21_10:33:58_PDT_2022
# Cuda compilation tools, release 11.8, V11.8.89
# Build cuda_11.8.r11.8/compiler.31833905_0

# %%
# %cd /content/drive/Othercomputers/Il mio PC/Dsktp_Gdrive/Common/test
# Out:
# /content/drive/Othercomputers/Il mio PC/Dsktp_Gdrive/Common/test

# %% [markdown]
# ## Compiling cuda test
#
# is going to be compiled ale_test_cuda.cpp that contains cuda headers that are needed to be linked to the cuda functions, nvcc do not recognise AVX instructions so i compile the .cu with nvcc, the rest with g++, and at the end link everything with nvcc

# %%
#compilazione a blocchi
# !nvcc -arch=sm_75 -c cuda_fun.cu -o cuda_functions.o
# Out:
# cuda_fun.cu: In function ‘void cudaFunction(float*, float*, float*, int, int, int)’:
# cuda_fun.cu:109:22: warning: ‘cudaError_t cudaThreadSynchronize()’ is deprecated [-Wdeprecated-declarations]
#   109 |         cudaThreadSynchronize();
#       |         ~~~~~~~~~~~~~^~
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cuda_runtime_api.h:1052:46: note: declared here
#  1052 | extern __CUDA_DEPRECATED __host__ cudaError_t CUDARTAPI cudaThreadSynchronize(void);
#       |                                              ^~~~~~~~~~~~~~~~~~~~~
# cuda_fun.cu:123:22: warning: ‘cudaError_t cudaThreadSynchronize()’ is deprecated [-Wdeprecated-declarations]
#   123 |         cudaThreadSynchronize();
#       |         ~~~~~~~~~~~~~^~
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cuda_runtime_api.h:1052:46: note: declared here
#  1052 | extern __CUDA_DEPRECATED __host__ cudaError_t CUDARTAPI cudaThreadSynchronize(void);
# ...

# %%
# !g++ -c -O3 -std=c++20  -march=native -ffast-math ale_test_cuda.cpp ../src/matrixProd_AVX.cpp  -mavx2 -mfma  -std=c++17

# %%
# !nvcc ale_test_cuda.o cuda_functions.o matrixProd_AVX.o -o executable_ale_cuda_test

# %% [markdown]
# ## Running the test
#
# this test is compiled for the T4 GPU on the colab notebook, do not run this locally !

# %%
# !chmod +x executable_ale_cuda_test
# %ll
# Out:
# total 971
# -rw------- 1 root  11004 Dec 11 08:12 ale_test_cuda.cpp
# -rw------- 1 root  63512 Dec 11 08:14 ale_test_cuda.o
# -rw------- 1 root  24120 Dec 11 08:13 cuda_functions.o
# -rw------- 1 root   4292 Dec 11 07:56 cuda_fun.cu
# -rw------- 1 root     70 Dec 10 18:52 cuda_launcher.h
# -rwx------ 1 root 884128 Dec 11 08:15 executable_ale_cuda_test*
# -rw------- 1 root   4384 Dec 11 08:14 matrixProd_AVX.o

# %%
# !./executable_ale_cuda_test
# Out:
# Building matricies...
# valori degli offset: 0000
# Test starting...
# passati valori 9.507423 0.954354
# in teoria funziona...
# Time elapsed on naive GPU matrix multiplication of 5000x5000 . 5000x5000 (4): 1587.288574 ms.
#
# Time elapsed on tiled (32) GPU matrix multiplication of 5000x5000 . 5000x5000 (4): 728.675842 ms.
#
# Time elapsed on naive GPU matrix multiplication of 5000x5000 . 5000x5000 (8): 1355.223022 ms.
#
# Time elapsed on tiled (32) GPU matrix multiplication of 5000x5000 . 5000x5000 (8): 372.106323 ms.
#
# Time elapsed on naive GPU matrix multiplication of 5000x5000 . 5000x5000 (16): 574.252930 ms.
#
# Time elapsed on tiled (32) GPU matrix multiplication of 5000x5000 . 5000x5000 (16): 292.734955 ms.
#
# Time elapsed on naive GPU matrix multiplication of 5000x5000 . 5000x5000 (32): 518.952942 ms.
#
# Time elapsed on tiled (32) GPU matrix multiplication of 5000x5000 . 5000x5000 (32): 297.175842 ms.
#
# Funziona !!
